# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# Phan tich du lieu sinh vien va tuong quan voi diem `G3`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from data_loader import correlation_with_target, load_data, missing_value_report

DATA_PATH = PROJECT_ROOT / 'data' / 'raw' / 'student-por-10.csv'
df = load_data(DATA_PATH)
df.head()

# %%
df.info()
df.describe()

# %%
missing_value_report(df)

# %%
corr = correlation_with_target(df)
corr.head(15)

# %%
plt.figure(figsize=(9, 6))
sns.barplot(x=corr.head(15).values, y=corr.head(15).index)
plt.title('Top 15 correlation with G3')
plt.xlabel('Correlation')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()
