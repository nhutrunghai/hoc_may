# %% [markdown]
# # 02 - Preprocessing
#
# Kiem tra missing values, ma hoa bien phan loai va chia train/test.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from data_loader import (
    load_data,
    make_preprocessor,
    missing_value_report,
    save_processed_dataset,
    split_features_target,
    train_test_split_data,
)

DATA_PATH = PROJECT_ROOT / 'data' / 'raw' / 'student-por-10.csv'
PROCESSED_PATH = PROJECT_ROOT / 'data' / 'processed' / 'student-por-10-processed.csv'
df = load_data(DATA_PATH)
df.head()

# %%
missing_value_report(df)

# %%
processed_df = save_processed_dataset(df, PROCESSED_PATH)
processed_df.head()

# %%
X, y = split_features_target(df)
X_train, X_test, y_train, y_test = train_test_split_data(X, y)

print('X_train:', X_train.shape)
print('X_test:', X_test.shape)
print('y_train:', y_train.shape)
print('y_test:', y_test.shape)

# %%
preprocessor = make_preprocessor(X_train)
X_train_encoded = preprocessor.fit_transform(X_train)
X_train_encoded.shape
